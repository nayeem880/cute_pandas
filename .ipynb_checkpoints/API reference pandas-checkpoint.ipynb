# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("INvideos.csv")
data
# Out:
#           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      zUZ1z7FwLc8      17.14.11
# 2      10L1hZ9qa58      17.14.11
# 3      N1vE8iiEg64      17.14.11
# 4      kJzGH0PVQHQ      17.14.11
# ...            ...           ...
# 37347  iNHecA3PJCo      18.14.06
# 37348  dpPmPbhcslM      18.14.06
# 37349  mV6aztP58f8      18.14.06
# 37350  qxqDNP1bDEw      18.14.06
# 37351  wERgpPK44w0      18.14.06
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...                TFPC
# 3                         Eruma Saani | Tamil vs English         Eruma Saani
# 4      why Samantha became EMOTIONAL @ Samantha naga ...          Filmylooks
# ...                                                  ...                 ...
# ...

# %%
data.head(5)
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  zUZ1z7FwLc8      17.14.11
# 2  10L1hZ9qa58      17.14.11
# 3  N1vE8iiEg64      17.14.11
# 4  kJzGH0PVQHQ      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
data.tail(5)
# Out:
#           video_id trending_date  \
# 37347  iNHecA3PJCo      18.14.06
# 37348  dpPmPbhcslM      18.14.06
# 37349  mV6aztP58f8      18.14.06
# 37350  qxqDNP1bDEw      18.14.06
# 37351  wERgpPK44w0      18.14.06
#
#                                                    title       channel_title  \
# 37347  फेकू आशिक़ - राजस्थान की सबसे शानदार कॉमेडी | ...      RDC Rajasthani
# 37348                         Seetha | Flowers | Ep# 364          Flowers TV
# 37349  Bhramanam I Episode 87 - 12 June 2018 I Mazhav...   Mazhavil Manorama
# 37350  Nua Bohu | Full Ep 285 | 13th June 2018 | Odia...           Tarang TV
# 37351  Ee Nagaraniki Emaindi Trailer | Tharun Bhascke...  Suresh Productions
#
#        category_id              publish_time  \
# 37347           23  2018-06-13T08:01:11.000Z
# 37348           24  2018-06-13T11:30:04.000Z
# 37349           24  2018-06-13T05:00:02.000Z
# 37350           24  2018-06-13T15:07:49.000Z
# 37351           24  2018-06-10T04:29:54.000Z
#
# ...

# %%
data.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  37352.000000  3.735200e+04  3.735200e+04  3.735200e+04    37352.00000
# mean      21.576596  1.060478e+06  2.708272e+04  1.665082e+03     2676.99743
# std        6.556593  3.184932e+06  9.714510e+04  1.607617e+04    14868.31713
# min        1.000000  4.024000e+03  0.000000e+00  0.000000e+00        0.00000
# 25%       23.000000  1.239155e+05  8.640000e+02  1.080000e+02       81.00000
# 50%       24.000000  3.045860e+05  3.069000e+03  3.260000e+02      329.00000
# 75%       24.000000  7.992912e+05  1.377425e+04  1.019250e+03     1285.00000
# max       43.000000  1.254322e+08  2.912710e+06  1.545017e+06   827755.00000

# %%
a= pd.read_clipboard(sep=',')
a #taken from the clipboard
# Out:
# Empty DataFrame
# Columns: [Linear algebra is the branch of mathematics concerning linear equations such as. linear functions such as. and their representations in vector spaces and through matrices. Linear algebra is central to almost all areas of mathematics.]
# Index: []

# %%
data.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
for i in data.columns:
    print(i)
# Out:
# video_id
# trending_date
# title
# channel_title
# category_id
# publish_time
# tags
# views
# likes
# dislikes
# comment_count
# thumbnail_link
# comments_disabled
# ratings_disabled
# video_error_or_removed
# description

# %%
len(data.index)
# Out:
# 37352

# %%
data.values
# Out:
# array([['kzwfHumJyYc', '17.14.11',
#         'Sharry Mann: Cute Munda ( Song Teaser) | Parmish Verma | Releasing on 17 November',
#         ..., False, False,
# ...

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=37352, step=1),
#  Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#         'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#         'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#         'video_error_or_removed', 'description'],
#        dtype='object')]

# %%
data.size
# Out:
# 597632

# %%
data.shape
# Out:
# (37352, 16)

# %%
data.ndim
# Out:
# 2

# %%
data.memory_usage #Return the memory usage of each column in bytes
# Out:
# <bound method DataFrame.memory_usage of           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      zUZ1z7FwLc8      17.14.11
# 2      10L1hZ9qa58      17.14.11
# 3      N1vE8iiEg64      17.14.11
# 4      kJzGH0PVQHQ      17.14.11
# ...            ...           ...
# 37347  iNHecA3PJCo      18.14.06
# 37348  dpPmPbhcslM      18.14.06
# 37349  mV6aztP58f8      18.14.06
# 37350  qxqDNP1bDEw      18.14.06
# 37351  wERgpPK44w0      18.14.06
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...                TFPC
# 3                         Eruma Saani | Tamil vs English         Eruma Saani
# 4      why Samantha became EMOTIONAL @ Samantha naga ...          Filmylooks
# ...

# %%
data.empty
# Out:
# False

# %%
a = data.copy()
a
# Out:
#           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      zUZ1z7FwLc8      17.14.11
# 2      10L1hZ9qa58      17.14.11
# 3      N1vE8iiEg64      17.14.11
# 4      kJzGH0PVQHQ      17.14.11
# ...            ...           ...
# 37347  iNHecA3PJCo      18.14.06
# 37348  dpPmPbhcslM      18.14.06
# 37349  mV6aztP58f8      18.14.06
# 37350  qxqDNP1bDEw      18.14.06
# 37351  wERgpPK44w0      18.14.06
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...                TFPC
# 3                         Eruma Saani | Tamil vs English         Eruma Saani
# 4      why Samantha became EMOTIONAL @ Samantha naga ...          Filmylooks
# ...                                                  ...                 ...
# ...

# %%
data.isna()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0         False          False  False          False        False
# 1         False          False  False          False        False
# 2         False          False  False          False        False
# 3         False          False  False          False        False
# 4         False          False  False          False        False
# ...         ...            ...    ...            ...          ...
# 37347     False          False  False          False        False
# 37348     False          False  False          False        False
# 37349     False          False  False          False        False
# 37350     False          False  False          False        False
# 37351     False          False  False          False        False
#
#        publish_time   tags  views  likes  dislikes  comment_count  \
# 0             False  False  False  False     False          False
# ...

# %%
data.notna()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0          True           True   True           True         True
# 1          True           True   True           True         True
# 2          True           True   True           True         True
# 3          True           True   True           True         True
# 4          True           True   True           True         True
# ...         ...            ...    ...            ...          ...
# 37347      True           True   True           True         True
# 37348      True           True   True           True         True
# 37349      True           True   True           True         True
# 37350      True           True   True           True         True
# 37351      True           True   True           True         True
#
#        publish_time  tags  views  likes  dislikes  comment_count  \
# 0              True  True   True   True      True           True
# ...

# %%
a.keys()
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')
